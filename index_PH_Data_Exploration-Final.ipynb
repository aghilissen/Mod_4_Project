# %% [markdown]
# PH Workbook:

# %% [markdown]
# ### Data Exploration

# %% [markdown]
# Motor Vehicle Deaths vs Independent Variables

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
sns.set_style('darkgrid') 

from statsmodels.formula.api import ols
from statsmodels.stats.outliers_influence import variance_inflation_factor
import statsmodels.api as sm
import scipy.stats as stats
from sklearn.model_selection import train_test_split

# %%
pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv('df.csv')
df.head()
df = df.dropna(axis=1,how='all')

# %%
subs = [(' ', '_'),('.',''),("'",""),('™', ''), ('®',''),
        ('+','plus'), ('½','half'), ('-','_'), ('<','under'), ('%','percent'), ('/', '_or_') 
       ]
def col_formatting(col):
    for old, new in subs:
        col = col.replace(old,new)
    return col

df.columns = [col_formatting(col) for col in df.columns]

# %%
del df['Years_of_Potential_Life_Lost_Rate']
df['percent_Rural'] = df['percent_Rural'].replace(np.nan, 0)

# %% [markdown]
# ### VIsual Exploration

# %%
target = 'MV_Mortality_Rate'
sns.jointplot(target,'percent_Excessive_Drinking', data=df, kind='reg');

# %%
sns.jointplot(target,'percent_65_and_over', data=df, kind='reg');

# %%
sns.jointplot(target,'Food_Environment_Index', data=df, kind='reg', color='red');

# %% [markdown]
# ### Checking for Multicollinearity

# %%
features = ['percent_Physically_Inactive',
         'percent_Excessive_Drinking',
         'percent_Alcohol_Impaired',
         'percent_Uninsured_x',
         'Average_Daily_PM25',
         'percent_Drive_Alone',
         'percent_Long_Commute___Drives_Alone',
         'percent_Frequent_Physical_Distress',
         'percent_Frequent_Mental_Distress',
         'percent_Insufficient_Sleep',
         'Household_Income',
         'Population_y',
         'percent_under_18',
         'percent_65_and_over',
         'percent_African_American',
         'percent_American_Indian_or_Alaskan_Native',
         'percent_Asian',
         'percent_Native_Hawaiian_or_Other_Pacific_Islander',
         'percent_Hispanic',
         'percent_Non_Hispanic_White',
         'percent_Not_Proficient_in_English',
         'percent_Female',
         'percent_Rural'
        ]

features_short = ['percent_Physically_Inactive',
         'percent_Excessive_Drinking',
         'percent_Alcohol_Impaired',
         'percent_Uninsured_x']

corr = df[features].corr()
corr
# Out:
#                                                    percent_Physically_Inactive  \
# percent_Physically_Inactive                                           1.000000
# percent_Excessive_Drinking                                           -0.562618
# percent_Alcohol_Impaired                                             -0.079836
# percent_Uninsured_x                                                   0.238215
# Average_Daily_PM25                                                    0.333244
# percent_Drive_Alone                                                   0.314471
# percent_Long_Commute___Drives_Alone                                   0.160794
# percent_Frequent_Physical_Distress                                    0.547685
# percent_Frequent_Mental_Distress                                      0.546388
# percent_Insufficient_Sleep                                            0.479812
# Household_Income                                                     -0.577904
# Population_y                                                         -0.213562
# percent_under_18                                                      0.066505
# percent_65_and_over                                                   0.118582
# percent_African_American                                              0.303530
# percent_American_Indian_or_Alaskan_Native                            -0.024387
# percent_Asian                                                        -0.329574
# percent_Native_Hawaiian_or_Other_Pacific_Islander                    -0.069433
# percent_Hispanic                                                     -0.222706
# percent_Non_Hispanic_White                                           -0.002632
# percent_Not_Proficient_in_English                                    -0.188890
# percent_Female                                                        0.100557
# percent_Rural                                                         0.337525
#
#                                                    percent_Excessive_Drinking  \
# percent_Physically_Inactive                                         -0.562618
# percent_Excessive_Drinking                                           1.000000
# percent_Alcohol_Impaired                                             0.146072
# percent_Uninsured_x                                                 -0.348184
# Average_Daily_PM25                                                  -0.204653
# percent_Drive_Alone                                                 -0.216059
# percent_Long_Commute___Drives_Alone                                 -0.150775
# percent_Frequent_Physical_Distress                                  -0.655196
# percent_Frequent_Mental_Distress                                    -0.659433
# percent_Insufficient_Sleep                                          -0.455225
# Household_Income                                                     0.539503
# Population_y                                                         0.116615
# percent_under_18                                                    -0.057803
# percent_65_and_over                                                 -0.162691
# percent_African_American                                            -0.363502
# percent_American_Indian_or_Alaskan_Native                           -0.006236
# percent_Asian                                                        0.179619
# percent_Native_Hawaiian_or_Other_Pacific_Islander                    0.013160
# percent_Hispanic                                                    -0.005061
# percent_Non_Hispanic_White                                           0.235220
# percent_Not_Proficient_in_English                                    0.007565
# percent_Female                                                      -0.189344
# percent_Rural                                                       -0.237913
#
#                                                    percent_Alcohol_Impaired  \
# percent_Physically_Inactive                                       -0.079836
# percent_Excessive_Drinking                                         0.146072
# percent_Alcohol_Impaired                                           1.000000
# percent_Uninsured_x                                               -0.078359
# Average_Daily_PM25                                                -0.181410
# percent_Drive_Alone                                               -0.120716
# percent_Long_Commute___Drives_Alone                               -0.035783
# percent_Frequent_Physical_Distress                                -0.054624
# percent_Frequent_Mental_Distress                                  -0.054923
# percent_Insufficient_Sleep                                        -0.088017
# Household_Income                                                   0.029019
# Population_y                                                      -0.020938
# percent_under_18                                                  -0.048225
# percent_65_and_over                                                0.071929
# percent_African_American                                          -0.048775
# percent_American_Indian_or_Alaskan_Native                          0.141282
# percent_Asian                                                      0.012500
# percent_Native_Hawaiian_or_Other_Pacific_Islander                  0.025101
# percent_Hispanic                                                  -0.092469
# percent_Non_Hispanic_White                                         0.036284
# percent_Not_Proficient_in_English                                 -0.083524
# percent_Female                                                    -0.050500
# percent_Rural                                                      0.077000
#
#                                                    percent_Uninsured_x  \
# percent_Physically_Inactive                                   0.238215
# percent_Excessive_Drinking                                   -0.348184
# percent_Alcohol_Impaired                                     -0.078359
# percent_Uninsured_x                                           1.000000
# Average_Daily_PM25                                           -0.166998
# percent_Drive_Alone                                          -0.124511
# percent_Long_Commute___Drives_Alone                          -0.071670
# percent_Frequent_Physical_Distress                            0.336521
# percent_Frequent_Mental_Distress                              0.263071
# percent_Insufficient_Sleep                                    0.063010
# Household_Income                                             -0.360481
# Population_y                                                 -0.071082
# percent_under_18                                              0.237631
# percent_65_and_over                                          -0.038399
# percent_African_American                                      0.180562
# percent_American_Indian_or_Alaskan_Native                     0.252247
# percent_Asian                                                -0.102214
# percent_Native_Hawaiian_or_Other_Pacific_Islander            -0.021692
# percent_Hispanic                                              0.438906
# percent_Non_Hispanic_White                                   -0.501915
# percent_Not_Proficient_in_English                             0.393207
# percent_Female                                               -0.101166
# percent_Rural                                                 0.167953
#
#                                                    Average_Daily_PM25  \
# percent_Physically_Inactive                                  0.333244
# percent_Excessive_Drinking                                  -0.204653
# percent_Alcohol_Impaired                                    -0.181410
# percent_Uninsured_x                                         -0.166998
# Average_Daily_PM25                                           1.000000
# percent_Drive_Alone                                          0.529734
# percent_Long_Commute___Drives_Alone                          0.365664
# percent_Frequent_Physical_Distress                           0.240263
# percent_Frequent_Mental_Distress                             0.278872
# percent_Insufficient_Sleep                                   0.483532
# Household_Income                                            -0.057079
# Population_y                                                 0.158192
# percent_under_18                                             0.034642
# percent_65_and_over                                         -0.206558
# percent_African_American                                     0.298081
# percent_American_Indian_or_Alaskan_Native                   -0.329274
# percent_Asian                                               -0.034926
# percent_Native_Hawaiian_or_Other_Pacific_Islander           -0.148774
# percent_Hispanic                                            -0.127083
# percent_Non_Hispanic_White                                   0.021431
# percent_Not_Proficient_in_English                           -0.049819
# percent_Female                                               0.266789
# percent_Rural                                               -0.202904
#
#                                                    percent_Drive_Alone  \
# percent_Physically_Inactive                                   0.314471
# percent_Excessive_Drinking                                   -0.216059
# percent_Alcohol_Impaired                                     -0.120716
# percent_Uninsured_x                                          -0.124511
# Average_Daily_PM25                                            0.529734
# percent_Drive_Alone                                           1.000000
# percent_Long_Commute___Drives_Alone                           0.172043
# percent_Frequent_Physical_Distress                            0.134902
# percent_Frequent_Mental_Distress                              0.159106
# percent_Insufficient_Sleep                                    0.279309
# Household_Income                                             -0.125857
# Population_y                                                 -0.116112
# percent_under_18                                              0.062504
# percent_65_and_over                                          -0.037726
# percent_African_American                                      0.176601
# percent_American_Indian_or_Alaskan_Native                    -0.329492
# percent_Asian                                                -0.273643
# percent_Native_Hawaiian_or_Other_Pacific_Islander            -0.145307
# percent_Hispanic                                             -0.112422
# percent_Non_Hispanic_White                                    0.131482
# percent_Not_Proficient_in_English                            -0.185354
# percent_Female                                                0.192522
# percent_Rural                                                -0.064984
#
#                                                    percent_Long_Commute___Drives_Alone  \
# percent_Physically_Inactive                                                   0.160794
# percent_Excessive_Drinking                                                   -0.150775
# percent_Alcohol_Impaired                                                     -0.035783
# percent_Uninsured_x                                                          -0.071670
# Average_Daily_PM25                                                            0.365664
# percent_Drive_Alone                                                           0.172043
# percent_Long_Commute___Drives_Alone                                           1.000000
# percent_Frequent_Physical_Distress                                            0.077444
# percent_Frequent_Mental_Distress                                              0.115918
# percent_Insufficient_Sleep                                                    0.306148
# Household_Income                                                              0.150340
# Population_y                                                                  0.125439
# percent_under_18                                                             -0.110645
# percent_65_and_over                                                          -0.019270
# percent_African_American                                                      0.177700
# percent_American_Indian_or_Alaskan_Native                                    -0.176115
# percent_Asian                                                                 0.024650
# percent_Native_Hawaiian_or_Other_Pacific_Islander                            -0.058058
# percent_Hispanic                                                             -0.127102
# percent_Non_Hispanic_White                                                    0.029210
# percent_Not_Proficient_in_English                                            -0.092009
# percent_Female                                                                0.081293
# percent_Rural                                                                 0.189173
#
#                                                    percent_Frequent_Physical_Distress  \
# percent_Physically_Inactive                                                  0.547685
# percent_Excessive_Drinking                                                  -0.655196
# percent_Alcohol_Impaired                                                    -0.054624
# percent_Uninsured_x                                                          0.336521
# Average_Daily_PM25                                                           0.240263
# percent_Drive_Alone                                                          0.134902
# percent_Long_Commute___Drives_Alone                                          0.077444
# percent_Frequent_Physical_Distress                                           1.000000
# percent_Frequent_Mental_Distress                                             0.956021
# percent_Insufficient_Sleep                                                   0.668226
# Household_Income                                                            -0.694037
# Population_y                                                                -0.098866
# percent_under_18                                                             0.084560
# percent_65_and_over                                                         -0.077385
# percent_African_American                                                     0.346866
# percent_American_Indian_or_Alaskan_Native                                    0.268826
# percent_Asian                                                               -0.217096
# percent_Native_Hawaiian_or_Other_Pacific_Islander                           -0.037253
# percent_Hispanic                                                             0.075926
# percent_Non_Hispanic_White                                                  -0.365147
# percent_Not_Proficient_in_English                                            0.053532
# percent_Female                                                               0.052078
# percent_Rural                                                                0.133368
#
#                                                    percent_Frequent_Mental_Distress  \
# percent_Physically_Inactive                                                0.546388
# percent_Excessive_Drinking                                                -0.659433
# percent_Alcohol_Impaired                                                  -0.054923
# percent_Uninsured_x                                                        0.263071
# Average_Daily_PM25                                                         0.278872
# percent_Drive_Alone                                                        0.159106
# percent_Long_Commute___Drives_Alone                                        0.115918
# percent_Frequent_Physical_Distress                                         0.956021
# percent_Frequent_Mental_Distress                                           1.000000
# percent_Insufficient_Sleep                                                 0.680780
# Household_Income                                                          -0.667454
# Population_y                                                              -0.102432
# percent_under_18                                                           0.027452
# percent_65_and_over                                                       -0.035499
# percent_African_American                                                   0.342071
# percent_American_Indian_or_Alaskan_Native                                  0.281886
# percent_Asian                                                             -0.233587
# percent_Native_Hawaiian_or_Other_Pacific_Islander                         -0.044417
# percent_Hispanic                                                          -0.082833
# percent_Non_Hispanic_White                                                -0.261064
# percent_Not_Proficient_in_English                                         -0.070837
# percent_Female                                                             0.148203
# percent_Rural                                                              0.139887
#
#                                                    percent_Insufficient_Sleep  \
# percent_Physically_Inactive                                          0.479812
# percent_Excessive_Drinking                                          -0.455225
# percent_Alcohol_Impaired                                            -0.088017
# percent_Uninsured_x                                                  0.063010
# Average_Daily_PM25                                                   0.483532
# percent_Drive_Alone                                                  0.279309
# percent_Long_Commute___Drives_Alone                                  0.306148
# percent_Frequent_Physical_Distress                                   0.668226
# percent_Frequent_Mental_Distress                                     0.680780
# percent_Insufficient_Sleep                                           1.000000
# Household_Income                                                    -0.315781
# Population_y                                                         0.080251
# percent_under_18                                                    -0.010503
# percent_65_and_over                                                 -0.257487
# percent_African_American                                             0.548037
# percent_American_Indian_or_Alaskan_Native                           -0.022854
# percent_Asian                                                        0.028972
# percent_Native_Hawaiian_or_Other_Pacific_Islander                    0.035838
# percent_Hispanic                                                    -0.079545
# percent_Non_Hispanic_White                                          -0.337539
# percent_Not_Proficient_in_English                                   -0.008598
# percent_Female                                                       0.102703
# percent_Rural                                                       -0.114779
#
#                                                    Household_Income  \
# percent_Physically_Inactive                               -0.577904
# percent_Excessive_Drinking                                 0.539503
# percent_Alcohol_Impaired                                   0.029019
# percent_Uninsured_x                                       -0.360481
# Average_Daily_PM25                                        -0.057079
# percent_Drive_Alone                                       -0.125857
# percent_Long_Commute___Drives_Alone                        0.150340
# percent_Frequent_Physical_Distress                        -0.694037
# percent_Frequent_Mental_Distress                          -0.667454
# percent_Insufficient_Sleep                                -0.315781
# Household_Income                                           1.000000
# Population_y                                               0.271010
# percent_under_18                                           0.081873
# percent_65_and_over                                       -0.287534
# percent_African_American                                  -0.241872
# percent_American_Indian_or_Alaskan_Native                 -0.102722
# percent_Asian                                              0.478975
# percent_Native_Hawaiian_or_Other_Pacific_Islander          0.075388
# percent_Hispanic                                           0.027196
# percent_Non_Hispanic_White                                 0.110902
# percent_Not_Proficient_in_English                          0.097068
# percent_Female                                             0.017682
# percent_Rural                                             -0.396200
#
#                                                    Population_y  \
# percent_Physically_Inactive                           -0.213562
# percent_Excessive_Drinking                             0.116615
# percent_Alcohol_Impaired                              -0.020938
# percent_Uninsured_x                                   -0.071082
# Average_Daily_PM25                                     0.158192
# percent_Drive_Alone                                   -0.116112
# percent_Long_Commute___Drives_Alone                    0.125439
# percent_Frequent_Physical_Distress                    -0.098866
# percent_Frequent_Mental_Distress                      -0.102432
# percent_Insufficient_Sleep                             0.080251
# Household_Income                                       0.271010
# Population_y                                           1.000000
# percent_under_18                                       0.034003
# percent_65_and_over                                   -0.215731
# percent_African_American                               0.076454
# percent_American_Indian_or_Alaskan_Native             -0.043082
# percent_Asian                                          0.459951
# percent_Native_Hawaiian_or_Other_Pacific_Islander      0.034197
# percent_Hispanic                                       0.195127
# percent_Non_Hispanic_White                            -0.240404
# percent_Not_Proficient_in_English                      0.295190
# percent_Female                                         0.119274
# percent_Rural                                         -0.395285
#
#                                                    percent_under_18  \
# percent_Physically_Inactive                                0.066505
# percent_Excessive_Drinking                                -0.057803
# percent_Alcohol_Impaired                                  -0.048225
# percent_Uninsured_x                                        0.237631
# Average_Daily_PM25                                         0.034642
# percent_Drive_Alone                                        0.062504
# percent_Long_Commute___Drives_Alone                       -0.110645
# percent_Frequent_Physical_Distress                         0.084560
# percent_Frequent_Mental_Distress                           0.027452
# percent_Insufficient_Sleep                                -0.010503
# Household_Income                                           0.081873
# Population_y                                               0.034003
# percent_under_18                                           1.000000
# percent_65_and_over                                       -0.587180
# percent_African_American                                  -0.020096
# percent_American_Indian_or_Alaskan_Native                  0.315025
# percent_Asian                                             -0.025120
# percent_Native_Hawaiian_or_Other_Pacific_Islander         -0.084289
# percent_Hispanic                                           0.310718
# percent_Non_Hispanic_White                                -0.301382
# percent_Not_Proficient_in_English                          0.298211
# percent_Female                                             0.179807
# percent_Rural                                             -0.159456
#
#                                                    percent_65_and_over  \
# percent_Physically_Inactive                                   0.118582
# percent_Excessive_Drinking                                   -0.162691
# percent_Alcohol_Impaired                                      0.071929
# percent_Uninsured_x                                          -0.038399
# Average_Daily_PM25                                           -0.206558
# percent_Drive_Alone                                          -0.037726
# percent_Long_Commute___Drives_Alone                          -0.019270
# percent_Frequent_Physical_Distress                           -0.077385
# percent_Frequent_Mental_Distress                             -0.035499
# percent_Insufficient_Sleep                                   -0.257487
# Household_Income                                             -0.287534
# Population_y                                                 -0.215731
# percent_under_18                                             -0.587180
# percent_65_and_over                                           1.000000
# percent_African_American                                     -0.187565
# percent_American_Indian_or_Alaskan_Native                    -0.154413
# percent_Asian                                                -0.291806
# percent_Native_Hawaiian_or_Other_Pacific_Islander             0.028217
# percent_Hispanic                                             -0.233904
# percent_Non_Hispanic_White                                    0.393735
# percent_Not_Proficient_in_English                            -0.289619
# percent_Female                                                0.074052
# percent_Rural                                                 0.485344
#
#                                                    percent_African_American  \
# percent_Physically_Inactive                                        0.303530
# percent_Excessive_Drinking                                        -0.363502
# percent_Alcohol_Impaired                                          -0.048775
# percent_Uninsured_x                                                0.180562
# Average_Daily_PM25                                                 0.298081
# percent_Drive_Alone                                                0.176601
# percent_Long_Commute___Drives_Alone                                0.177700
# percent_Frequent_Physical_Distress                                 0.346866
# percent_Frequent_Mental_Distress                                   0.342071
# percent_Insufficient_Sleep                                         0.548037
# Household_Income                                                  -0.241872
# Population_y                                                       0.076454
# percent_under_18                                                  -0.020096
# percent_65_and_over                                               -0.187565
# percent_African_American                                           1.000000
# percent_American_Indian_or_Alaskan_Native                         -0.109735
# percent_Asian                                                      0.022975
# percent_Native_Hawaiian_or_Other_Pacific_Islander                 -0.023905
# percent_Hispanic                                                  -0.107490
# percent_Non_Hispanic_White                                        -0.595126
# percent_Not_Proficient_in_English                                 -0.035676
# percent_Female                                                     0.144348
# percent_Rural                                                     -0.119558
#
#                                                    percent_American_Indian_or_Alaskan_Native  \
# percent_Physically_Inactive                                                        -0.024387
# percent_Excessive_Drinking                                                         -0.006236
# percent_Alcohol_Impaired                                                            0.141282
# percent_Uninsured_x                                                                 0.252247
# Average_Daily_PM25                                                                 -0.329274
# percent_Drive_Alone                                                                -0.329492
# percent_Long_Commute___Drives_Alone                                                -0.176115
# percent_Frequent_Physical_Distress                                                  0.268826
# percent_Frequent_Mental_Distress                                                    0.281886
# percent_Insufficient_Sleep                                                         -0.022854
# Household_Income                                                                   -0.102722
# Population_y                                                                       -0.043082
# percent_under_18                                                                    0.315025
# percent_65_and_over                                                                -0.154413
# percent_African_American                                                           -0.109735
# percent_American_Indian_or_Alaskan_Native                                           1.000000
# percent_Asian                                                                      -0.015749
# percent_Native_Hawaiian_or_Other_Pacific_Islander                                   0.004271
# percent_Hispanic                                                                    0.002416
# percent_Non_Hispanic_White                                                         -0.315078
# percent_Not_Proficient_in_English                                                  -0.009835
# percent_Female                                                                     -0.079401
# percent_Rural                                                                       0.096425
#
#                                                    percent_Asian  \
# percent_Physically_Inactive                            -0.329574
# percent_Excessive_Drinking                              0.179619
# percent_Alcohol_Impaired                                0.012500
# percent_Uninsured_x                                    -0.102214
# Average_Daily_PM25                                     -0.034926
# percent_Drive_Alone                                    -0.273643
# percent_Long_Commute___Drives_Alone                     0.024650
# percent_Frequent_Physical_Distress                     -0.217096
# percent_Frequent_Mental_Distress                       -0.233587
# percent_Insufficient_Sleep                              0.028972
# Household_Income                                        0.478975
# Population_y                                            0.459951
# percent_under_18                                       -0.025120
# percent_65_and_over                                    -0.291806
# percent_African_American                                0.022975
# percent_American_Indian_or_Alaskan_Native              -0.015749
# percent_Asian                                           1.000000
# percent_Native_Hawaiian_or_Other_Pacific_Islander       0.248724
# percent_Hispanic                                        0.161949
# percent_Non_Hispanic_White                             -0.294838
# percent_Not_Proficient_in_English                       0.317858
# percent_Female                                         -0.002490
# percent_Rural                                          -0.424953
#
#                                                    percent_Native_Hawaiian_or_Other_Pacific_Islander  \
# percent_Physically_Inactive                                                                -0.069433
# percent_Excessive_Drinking                                                                  0.013160
# percent_Alcohol_Impaired                                                                    0.025101
# percent_Uninsured_x                                                                        -0.021692
# Average_Daily_PM25                                                                         -0.148774
# percent_Drive_Alone                                                                        -0.145307
# percent_Long_Commute___Drives_Alone                                                        -0.058058
# percent_Frequent_Physical_Distress                                                         -0.037253
# percent_Frequent_Mental_Distress                                                           -0.044417
# percent_Insufficient_Sleep                                                                  0.035838
# Household_Income                                                                            0.075388
# Population_y                                                                                0.034197
# percent_under_18                                                                           -0.084289
# percent_65_and_over                                                                         0.028217
# percent_African_American                                                                   -0.023905
# percent_American_Indian_or_Alaskan_Native                                                   0.004271
# percent_Asian                                                                               0.248724
# percent_Native_Hawaiian_or_Other_Pacific_Islander                                           1.000000
# percent_Hispanic                                                                            0.028888
# percent_Non_Hispanic_White                                                                 -0.112605
# percent_Not_Proficient_in_English                                                           0.084919
# percent_Female                                                                             -0.001009
# percent_Rural                                                                              -0.037799
#
#                                                    percent_Hispanic  \
# percent_Physically_Inactive                               -0.222706
# percent_Excessive_Drinking                                -0.005061
# percent_Alcohol_Impaired                                  -0.092469
# percent_Uninsured_x                                        0.438906
# Average_Daily_PM25                                        -0.127083
# percent_Drive_Alone                                       -0.112422
# percent_Long_Commute___Drives_Alone                       -0.127102
# percent_Frequent_Physical_Distress                         0.075926
# percent_Frequent_Mental_Distress                          -0.082833
# percent_Insufficient_Sleep                                -0.079545
# Household_Income                                           0.027196
# Population_y                                               0.195127
# percent_under_18                                           0.310718
# percent_65_and_over                                       -0.233904
# percent_African_American                                  -0.107490
# percent_American_Indian_or_Alaskan_Native                  0.002416
# percent_Asian                                              0.161949
# percent_Native_Hawaiian_or_Other_Pacific_Islander          0.028888
# percent_Hispanic                                           1.000000
# percent_Non_Hispanic_White                                -0.607415
# percent_Not_Proficient_in_English                          0.808373
# percent_Female                                            -0.142765
# percent_Rural                                             -0.281970
#
#                                                    percent_Non_Hispanic_White  \
# percent_Physically_Inactive                                         -0.002632
# percent_Excessive_Drinking                                           0.235220
# percent_Alcohol_Impaired                                             0.036284
# percent_Uninsured_x                                                 -0.501915
# Average_Daily_PM25                                                   0.021431
# percent_Drive_Alone                                                  0.131482
# percent_Long_Commute___Drives_Alone                                  0.029210
# percent_Frequent_Physical_Distress                                  -0.365147
# percent_Frequent_Mental_Distress                                    -0.261064
# percent_Insufficient_Sleep                                          -0.337539
# Household_Income                                                     0.110902
# Population_y                                                        -0.240404
# percent_under_18                                                    -0.301382
# percent_65_and_over                                                  0.393735
# percent_African_American                                            -0.595126
# percent_American_Indian_or_Alaskan_Native                           -0.315078
# percent_Asian                                                       -0.294838
# percent_Native_Hawaiian_or_Other_Pacific_Islander                   -0.112605
# percent_Hispanic                                                    -0.607415
# percent_Non_Hispanic_White                                           1.000000
# percent_Not_Proficient_in_English                                   -0.553853
# percent_Female                                                       0.022090
# percent_Rural                                                        0.308041
#
#                                                    percent_Not_Proficient_in_English  \
# percent_Physically_Inactive                                                -0.188890
# percent_Excessive_Drinking                                                  0.007565
# percent_Alcohol_Impaired                                                   -0.083524
# percent_Uninsured_x                                                         0.393207
# Average_Daily_PM25                                                         -0.049819
# percent_Drive_Alone                                                        -0.185354
# percent_Long_Commute___Drives_Alone                                        -0.092009
# percent_Frequent_Physical_Distress                                          0.053532
# percent_Frequent_Mental_Distress                                           -0.070837
# percent_Insufficient_Sleep                                                 -0.008598
# Household_Income                                                            0.097068
# Population_y                                                                0.295190
# percent_under_18                                                            0.298211
# percent_65_and_over                                                        -0.289619
# percent_African_American                                                   -0.035676
# percent_American_Indian_or_Alaskan_Native                                  -0.009835
# percent_Asian                                                               0.317858
# percent_Native_Hawaiian_or_Other_Pacific_Islander                           0.084919
# percent_Hispanic                                                            0.808373
# percent_Non_Hispanic_White                                                 -0.553853
# percent_Not_Proficient_in_English                                           1.000000
# percent_Female                                                             -0.102848
# percent_Rural                                                              -0.307599
#
#                                                    percent_Female  \
# percent_Physically_Inactive                              0.100557
# percent_Excessive_Drinking                              -0.189344
# percent_Alcohol_Impaired                                -0.050500
# percent_Uninsured_x                                     -0.101166
# Average_Daily_PM25                                       0.266789
# percent_Drive_Alone                                      0.192522
# percent_Long_Commute___Drives_Alone                      0.081293
# percent_Frequent_Physical_Distress                       0.052078
# percent_Frequent_Mental_Distress                         0.148203
# percent_Insufficient_Sleep                               0.102703
# Household_Income                                         0.017682
# Population_y                                             0.119274
# percent_under_18                                         0.179807
# percent_65_and_over                                      0.074052
# percent_African_American                                 0.144348
# percent_American_Indian_or_Alaskan_Native               -0.079401
# percent_Asian                                           -0.002490
# percent_Native_Hawaiian_or_Other_Pacific_Islander       -0.001009
# percent_Hispanic                                        -0.142765
# percent_Non_Hispanic_White                               0.022090
# percent_Not_Proficient_in_English                       -0.102848
# percent_Female                                           1.000000
# percent_Rural                                           -0.191557
#
#                                                    percent_Rural
# percent_Physically_Inactive                             0.337525
# percent_Excessive_Drinking                             -0.237913
# percent_Alcohol_Impaired                                0.077000
# percent_Uninsured_x                                     0.167953
# Average_Daily_PM25                                     -0.202904
# percent_Drive_Alone                                    -0.064984
# percent_Long_Commute___Drives_Alone                     0.189173
# percent_Frequent_Physical_Distress                      0.133368
# percent_Frequent_Mental_Distress                        0.139887
# percent_Insufficient_Sleep                             -0.114779
# Household_Income                                       -0.396200
# Population_y                                           -0.395285
# percent_under_18                                       -0.159456
# percent_65_and_over                                     0.485344
# percent_African_American                               -0.119558
# percent_American_Indian_or_Alaskan_Native               0.096425
# percent_Asian                                          -0.424953
# percent_Native_Hawaiian_or_Other_Pacific_Islander      -0.037799
# percent_Hispanic                                       -0.281970
# percent_Non_Hispanic_White                              0.308041
# percent_Not_Proficient_in_English                      -0.307599
# percent_Female                                         -0.191557
# percent_Rural                                           1.000000

# %% [markdown]
# ### Heatmap

# %%
sns.heatmap(corr, center=0, annot=True);

# %% [markdown]
# ### Modelling the Data

# %% [markdown]
# Import the necessary libraries for the modelling phase

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
sns.set_style('darkgrid')

from statsmodels.formula.api import ols
from statsmodels.stats.outliers_influence import variance_inflation_factor
import statsmodels.api as sm
import scipy.stats as stats
from sklearn.model_selection import train_test_split

# %% [markdown]
# ##### Abitrary Selection of Explanatory Variables
#
# Define the target variable and the independent and explanatory variables

# %%
outcome = target
# x_cols = list(df.columns)
# x_cols.remove(outcome)

x_cols = ['percent_Physically_Inactive',
         'percent_Excessive_Drinking',
         'percent_Alcohol_Impaired',
         'percent_Uninsured_x',
         'Average_Daily_PM25',
         'percent_Drive_Alone',
         'percent_Long_Commute___Drives_Alone',
         'percent_Frequent_Physical_Distress',
         'percent_Frequent_Mental_Distress',
         'percent_Insufficient_Sleep',
         'Household_Income',
         'Population_y',
         'percent_under_18',
         'percent_65_and_over',
         'percent_African_American',
         'percent_American_Indian_or_Alaskan_Native',
         'percent_Asian',
         'percent_Native_Hawaiian_or_Other_Pacific_Islander',
         'percent_Hispanic',
         'percent_Non_Hispanic_White',
         'percent_Not_Proficient_in_English',
         'percent_Female',
         'percent_Rural'
        ]

x_cols_short = ['percent_Physically_Inactive',
         'percent_Excessive_Drinking',
         'percent_Alcohol_Impaired',
         'percent_Uninsured_x',
         ]

# %%
df['percent_LBW'].fillna(0, inplace = True)
df['Food_Environment_Index'].fillna(df['Food_Environment_Index'].mean(), inplace = True)
df['percent_With_Access'].fillna(0, inplace = True)
df['percent_Alcohol_Impaired'].fillna(0, inplace = True)
df['percent_Uninsured_x'].fillna(0, inplace = True)
df['Chlamydia_Rate'].fillna(0, inplace = True)
df['Teen_Birth_Rate'].fillna(0, inplace = True)

# %% [markdown]
# ### Test train split

# %%
#### Must standardize - Ask where we do it

# %%
train, test = train_test_split(df)
train.head(2)
# Out:
#        FIPS    State     County  YPLL_Rate_(Black)  YPLL_Rate_(Hispanic)  \
# 1619  30043  Montana  Jefferson                NaN                   NaN
# 2709  48373    Texas       Polk        9292.114408           6229.232289
#
#       YPLL_Rate_(White)  percent_Fair_or_Poor  Physically_Unhealthy_Days  \
# 1619                NaN             10.652614                   3.012596
# 2709       12510.561117             19.017365                   3.811287
#
#       Mentally_Unhealthy_Days  percent_LBW  percent_LBW_(Black)  \
# 1619                 3.050505     6.623586                  NaN
# 2709                 3.792325     7.637907            13.311688
#
#       percent_LBW_(Hispanic)  percent_LBW_(White)  percent_Smokers  \
# 1619                     NaN                  NaN        14.692034
# 2709                7.109737             7.099391        17.256215
#
#       percent_Obese  Food_Environment_Index  percent_Physically_Inactive  \
# 1619           26.5                     8.8                         16.3
# 2709           33.5                     6.1                         26.9
#
#       percent_With_Access  percent_Excessive_Drinking  \
# 1619            56.522883                   20.042994
# 2709            41.067536                   17.477044
#
#       percent_Alcohol_Impaired  Chlamydia_Rate  Teen_Birth_Rate  \
# 1619                 28.571429           128.8        13.926499
# 2709                 17.910448           321.5        54.845457
#
#       Teen_Birth_Rate_(Black)  Teen_Birth_Rate_(Hispanic)  \
# 1619                      NaN                         NaN
# 2709                52.529183                   46.190762
#
#       Teen_Birth_Rate_(White)  percent_Uninsured_x  PCP_Rate PCP_Ratio  \
# 1619                      NaN             8.637092  75.93014    1317:1
# 2709                59.120404            21.903908  52.17464    1917:1
#
#       Dentist_Rate Dentist_Ratio  MHP_Rate MHP_Ratio  Preventable_Hosp_Rate  \
# 1619      50.45833        1982:1  67.27777    1486:1                 3144.0
# 2709      32.54546        3073:1  34.57955    2892:1                 3136.0
#
#       Preventable_Hosp_Rate_(Black)  Preventable_Hosp_Rate_(Hispanic)  \
# 1619                            NaN                               NaN
# 2709                         4281.0                               NaN
#
#       Preventable_Hosp_Rate_(White)  percent_Screened  \
# 1619                            NaN              39.0
# 2709                         3135.0              39.0
#
#       percent_Screened_(Black)  percent_Screened_(Hispanic)  \
# 1619                       NaN                          NaN
# 2709                      39.0                         33.0
#
#       percent_Screened_(White)  percent_Vaccinated  \
# 1619                       NaN                39.0
# 2709                      40.0                43.0
#
#       percent_Vaccinated_(Black)  percent_Vaccinated_(Hispanic)  \
# 1619                         NaN                            NaN
# 2709                        30.0                           36.0
#
#       percent_Vaccinated_(White)  Cohort_Size  Graduation_Rate  Population_x  \
# 1619                         NaN          NaN            80.46          2195
# 2709                        43.0        439.0            92.10         10828
#
#       percent_Some_College  Labor_Force  percent_Unemployed  \
# 1619             72.072893       5645.0            4.304694
# 2709             42.288511      17435.0            6.016633
#
#       percent_Children_in_Poverty  percent_Children_in_Poverty_(Black)  \
# 1619                          9.5                                  NaN
# 2709                         28.7                            43.065693
#
#       percent_Children_in_Poverty_(Hispanic)  \
# 1619                               31.884058
# 2709                               33.518987
#
#       percent_Children_in_Poverty_(White)  80th_Percentile_Income  \
# 1619                            10.664172                  117817
# 2709                            30.945224                   88500
#
#       20th_Percentile_Income  Income_Ratio  percent_Single_Parent_Households  \
# 1619                   28258      4.169333                         27.692308
# 2709                   18561      4.768062                         45.983120
#
#       Association_Rate  Annual_Average_Violent_Crimes  Violent_Crime_Rate  \
# 1619          7.593014                           37.0          318.074361
# 2709          9.391435                          133.5          286.014226
#
#       Injury_Death_Rate  Average_Daily_PM25 Presence_of_violation  \
# 1619          97.504234                 7.3                   Yes
# 2709         114.022186                 9.9                   Yes
#
#       percent_Severe_Housing_Problems  Severe_Housing_Cost_Burden  \
# 1619                         8.938547                    7.858590
# 2709                        15.102975                    9.971082
#
#       Overcrowding  Inadequate_Facilities  percent_Drive_Alone  \
# 1619      0.871508               0.178771            75.546186
# 2709      3.718535               2.059497            77.661254
#
#       percent_Drive_Alone_(Black)  percent_Drive_Alone_(Hispanic)  \
# 1619                          NaN                             NaN
# 2709                    84.724122                       78.333333
#
#       percent_Drive_Alone_(White)  percent_Long_Commute___Drives_Alone  \
# 1619                          NaN                                 22.5
# 2709                    76.780214                                 35.1
#
#       Life_Expectancy  Life_Expectancy_(Black)  Life_Expectancy_(Hispanic)  \
# 1619        80.081623                      NaN                         NaN
# 2709        73.339720                74.728363                    83.34245
#
#       Life_Expectancy_(White)  Age_Adjusted_Mortality  \
# 1619                      NaN                   276.0
# 2709                72.103891                   520.4
#
#       Age_Adjusted_Mortality_(Black)  Age_Adjusted_Mortality_(Hispanic)  \
# 1619                             NaN                                NaN
# 2709                      501.251686                         327.501027
#
#       Age_Adjusted_Mortality_(White)  Child_Mortality_Rate  \
# 1619                             NaN                   NaN
# 2709                      566.369466             51.370303
#
#       Child_Mortality_Rate_(Black)  Child_Mortality_Rate_(Hispanic)  \
# 1619                           NaN                              NaN
# 2709                           NaN                              NaN
#
#       Child_Mortality_Rate_(White)  Infant_Mortality_Rate  \
# 1619                           NaN                    NaN
# 2709                           NaN               5.862647
#
#       Infant_Mortality_Rate_(Black)  Infant_Mortality_Rate_(Hispanic)  \
# 1619                            NaN                               NaN
# 2709                            NaN                               NaN
#
#       Infant_Mortality_Rate_(White)  percent_Frequent_Physical_Distress  \
# 1619                            NaN                            9.090241
# 2709                            NaN                           11.821948
#
#       percent_Frequent_Mental_Distress  percent_Diabetic  HIV_Prevalence_Rate  \
# 1619                          9.617527               8.2                 59.4
# 2709                         11.872587              12.0                421.6
#
#       percent_Food_Insecure  percent_Limited_Access  \
# 1619                    9.5                2.549469
# 2709                   19.4               11.768500
#
#       Drug_Overdose_Mortality_Rate  MV_Mortality_Rate  \
# 1619                           NaN          17.232678
# 2709                     11.801458          30.553009
#
#       percent_Insufficient_Sleep  percent_Uninsured_y  percent_Uninsured1  \
# 1619                   25.387581             9.842857            5.284068
# 2709                   32.341667            26.013459           11.660917
#
#       Other_PCP_Rate Other_PCP_Ratio  percent_Disconnected_Youth  \
# 1619        33.63889          2973:1                         NaN
# 2709        44.75001          2235:1                   18.988465
#
#       Household_Income  Household_income_(Black)  Household_income_(Hispanic)  \
# 1619           66813.0                       NaN                      52269.0
# 2709           44596.0                   33234.0                      35787.0
#
#       Household_income_(White)  percent_Free_or_Reduced_Lunch  \
# 1619                   64911.0                      28.123077
# 2709                   47619.0                      67.647483
#
#       Segregation_index  Segregation_Index  Homicide_Rate  \
# 1619                NaN          42.302228            NaN
# 2709          47.306944          42.754309            5.8
#
#       Firearm_Fatalities_Rate  percent_Homeowners  \
# 1619                     22.2           85.106383
# 2709                     17.4           76.695780
#
#       percent_Severe_Housing_Cost_Burden  Population_y  percent_under_18  \
# 1619                            8.603145         11891         20.326297
# 2709                           11.561383         49162         20.536186
#
#       percent_65_and_over  percent_African_American  \
# 1619            20.713144                  0.302750
# 2709            18.656686                  9.969082
#
#       percent_American_Indian_or_Alaskan_Native  percent_Asian  \
# 1619                                   1.774451       0.479354
# 2709                                   2.292421       0.774989
#
#       percent_Native_Hawaiian_or_Other_Pacific_Islander  percent_Hispanic  \
# 1619                                           0.050458          2.329493
# 2709                                           0.081364         15.306538
#
#       percent_Non_Hispanic_White  percent_Not_Proficient_in_English  \
# 1619                   93.162896                           0.026930
# 2709                   70.896221                           3.344662
#
#       percent_Female  percent_Rural
# 1619       49.390295     100.000000
# 2709       46.068101      77.638562

# %%
print(len(train), len(test))
train.head(2)
# Out:
# 2356 786
#        FIPS    State     County  YPLL_Rate_(Black)  YPLL_Rate_(Hispanic)  \
# 1619  30043  Montana  Jefferson                NaN                   NaN
# 2709  48373    Texas       Polk        9292.114408           6229.232289
#
#       YPLL_Rate_(White)  percent_Fair_or_Poor  Physically_Unhealthy_Days  \
# 1619                NaN             10.652614                   3.012596
# 2709       12510.561117             19.017365                   3.811287
#
#       Mentally_Unhealthy_Days  percent_LBW  percent_LBW_(Black)  \
# 1619                 3.050505     6.623586                  NaN
# 2709                 3.792325     7.637907            13.311688
#
#       percent_LBW_(Hispanic)  percent_LBW_(White)  percent_Smokers  \
# 1619                     NaN                  NaN        14.692034
# 2709                7.109737             7.099391        17.256215
#
#       percent_Obese  Food_Environment_Index  percent_Physically_Inactive  \
# 1619           26.5                     8.8                         16.3
# 2709           33.5                     6.1                         26.9
#
#       percent_With_Access  percent_Excessive_Drinking  \
# 1619            56.522883                   20.042994
# 2709            41.067536                   17.477044
#
#       percent_Alcohol_Impaired  Chlamydia_Rate  Teen_Birth_Rate  \
# 1619                 28.571429           128.8        13.926499
# 2709                 17.910448           321.5        54.845457
#
#       Teen_Birth_Rate_(Black)  Teen_Birth_Rate_(Hispanic)  \
# 1619                      NaN                         NaN
# 2709                52.529183                   46.190762
#
#       Teen_Birth_Rate_(White)  percent_Uninsured_x  PCP_Rate PCP_Ratio  \
# 1619                      NaN             8.637092  75.93014    1317:1
# 2709                59.120404            21.903908  52.17464    1917:1
#
#       Dentist_Rate Dentist_Ratio  MHP_Rate MHP_Ratio  Preventable_Hosp_Rate  \
# 1619      50.45833        1982:1  67.27777    1486:1                 3144.0
# 2709      32.54546        3073:1  34.57955    2892:1                 3136.0
#
#       Preventable_Hosp_Rate_(Black)  Preventable_Hosp_Rate_(Hispanic)  \
# 1619                            NaN                               NaN
# 2709                         4281.0                               NaN
#
#       Preventable_Hosp_Rate_(White)  percent_Screened  \
# 1619                            NaN              39.0
# 2709                         3135.0              39.0
#
#       percent_Screened_(Black)  percent_Screened_(Hispanic)  \
# 1619                       NaN                          NaN
# 2709                      39.0                         33.0
#
#       percent_Screened_(White)  percent_Vaccinated  \
# 1619                       NaN                39.0
# 2709                      40.0                43.0
#
#       percent_Vaccinated_(Black)  percent_Vaccinated_(Hispanic)  \
# 1619                         NaN                            NaN
# 2709                        30.0                           36.0
#
#       percent_Vaccinated_(White)  Cohort_Size  Graduation_Rate  Population_x  \
# 1619                         NaN          NaN            80.46          2195
# 2709                        43.0        439.0            92.10         10828
#
#       percent_Some_College  Labor_Force  percent_Unemployed  \
# 1619             72.072893       5645.0            4.304694
# 2709             42.288511      17435.0            6.016633
#
#       percent_Children_in_Poverty  percent_Children_in_Poverty_(Black)  \
# 1619                          9.5                                  NaN
# 2709                         28.7                            43.065693
#
#       percent_Children_in_Poverty_(Hispanic)  \
# 1619                               31.884058
# 2709                               33.518987
#
#       percent_Children_in_Poverty_(White)  80th_Percentile_Income  \
# 1619                            10.664172                  117817
# 2709                            30.945224                   88500
#
#       20th_Percentile_Income  Income_Ratio  percent_Single_Parent_Households  \
# 1619                   28258      4.169333                         27.692308
# 2709                   18561      4.768062                         45.983120
#
#       Association_Rate  Annual_Average_Violent_Crimes  Violent_Crime_Rate  \
# 1619          7.593014                           37.0          318.074361
# 2709          9.391435                          133.5          286.014226
#
#       Injury_Death_Rate  Average_Daily_PM25 Presence_of_violation  \
# 1619          97.504234                 7.3                   Yes
# 2709         114.022186                 9.9                   Yes
#
#       percent_Severe_Housing_Problems  Severe_Housing_Cost_Burden  \
# 1619                         8.938547                    7.858590
# 2709                        15.102975                    9.971082
#
#       Overcrowding  Inadequate_Facilities  percent_Drive_Alone  \
# 1619      0.871508               0.178771            75.546186
# 2709      3.718535               2.059497            77.661254
#
#       percent_Drive_Alone_(Black)  percent_Drive_Alone_(Hispanic)  \
# 1619                          NaN                             NaN
# 2709                    84.724122                       78.333333
#
#       percent_Drive_Alone_(White)  percent_Long_Commute___Drives_Alone  \
# 1619                          NaN                                 22.5
# 2709                    76.780214                                 35.1
#
#       Life_Expectancy  Life_Expectancy_(Black)  Life_Expectancy_(Hispanic)  \
# 1619        80.081623                      NaN                         NaN
# 2709        73.339720                74.728363                    83.34245
#
#       Life_Expectancy_(White)  Age_Adjusted_Mortality  \
# 1619                      NaN                   276.0
# 2709                72.103891                   520.4
#
#       Age_Adjusted_Mortality_(Black)  Age_Adjusted_Mortality_(Hispanic)  \
# 1619                             NaN                                NaN
# 2709                      501.251686                         327.501027
#
#       Age_Adjusted_Mortality_(White)  Child_Mortality_Rate  \
# 1619                             NaN                   NaN
# 2709                      566.369466             51.370303
#
#       Child_Mortality_Rate_(Black)  Child_Mortality_Rate_(Hispanic)  \
# 1619                           NaN                              NaN
# 2709                           NaN                              NaN
#
#       Child_Mortality_Rate_(White)  Infant_Mortality_Rate  \
# 1619                           NaN                    NaN
# 2709                           NaN               5.862647
#
#       Infant_Mortality_Rate_(Black)  Infant_Mortality_Rate_(Hispanic)  \
# 1619                            NaN                               NaN
# 2709                            NaN                               NaN
#
#       Infant_Mortality_Rate_(White)  percent_Frequent_Physical_Distress  \
# 1619                            NaN                            9.090241
# 2709                            NaN                           11.821948
#
#       percent_Frequent_Mental_Distress  percent_Diabetic  HIV_Prevalence_Rate  \
# 1619                          9.617527               8.2                 59.4
# 2709                         11.872587              12.0                421.6
#
#       percent_Food_Insecure  percent_Limited_Access  \
# 1619                    9.5                2.549469
# 2709                   19.4               11.768500
#
#       Drug_Overdose_Mortality_Rate  MV_Mortality_Rate  \
# 1619                           NaN          17.232678
# 2709                     11.801458          30.553009
#
#       percent_Insufficient_Sleep  percent_Uninsured_y  percent_Uninsured1  \
# 1619                   25.387581             9.842857            5.284068
# 2709                   32.341667            26.013459           11.660917
#
#       Other_PCP_Rate Other_PCP_Ratio  percent_Disconnected_Youth  \
# 1619        33.63889          2973:1                         NaN
# 2709        44.75001          2235:1                   18.988465
#
#       Household_Income  Household_income_(Black)  Household_income_(Hispanic)  \
# 1619           66813.0                       NaN                      52269.0
# 2709           44596.0                   33234.0                      35787.0
#
#       Household_income_(White)  percent_Free_or_Reduced_Lunch  \
# 1619                   64911.0                      28.123077
# 2709                   47619.0                      67.647483
#
#       Segregation_index  Segregation_Index  Homicide_Rate  \
# 1619                NaN          42.302228            NaN
# 2709          47.306944          42.754309            5.8
#
#       Firearm_Fatalities_Rate  percent_Homeowners  \
# 1619                     22.2           85.106383
# 2709                     17.4           76.695780
#
#       percent_Severe_Housing_Cost_Burden  Population_y  percent_under_18  \
# 1619                            8.603145         11891         20.326297
# 2709                           11.561383         49162         20.536186
#
#       percent_65_and_over  percent_African_American  \
# 1619            20.713144                  0.302750
# 2709            18.656686                  9.969082
#
#       percent_American_Indian_or_Alaskan_Native  percent_Asian  \
# 1619                                   1.774451       0.479354
# 2709                                   2.292421       0.774989
#
#       percent_Native_Hawaiian_or_Other_Pacific_Islander  percent_Hispanic  \
# 1619                                           0.050458          2.329493
# 2709                                           0.081364         15.306538
#
#       percent_Non_Hispanic_White  percent_Not_Proficient_in_English  \
# 1619                   93.162896                           0.026930
# 2709                   70.896221                           3.344662
#
#       percent_Female  percent_Rural
# 1619       49.390295     100.000000
# 2709       46.068101      77.638562

# %%
predictors = '+'.join(x_cols)
formula = outcome + '~' + predictors
model = ols(formula=formula, data=train).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:      MV_Mortality_Rate   R-squared:                       0.546
# Model:                            OLS   Adj. R-squared:                  0.542
# Method:                 Least Squares   F-statistic:                     121.9
# Date:                Tue, 25 Feb 2020   Prob (F-statistic):               0.00
# Time:                        09:20:32   Log-Likelihood:                -7515.9
# No. Observations:                2356   AIC:                         1.508e+04
# Df Residuals:                    2332   BIC:                         1.522e+04
# Df Model:                          23
# Covariance Type:            nonrobust
# =====================================================================================================================
#                                                         coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------------------------
# Intercept                                           -53.8367     13.393     -4.020      0.000     -80.100     -27.573
# percent_Physically_Inactive                           0.3933      0.038     10.480      0.000       0.320       0.467
# percent_Excessive_Drinking                           -0.1602      0.062     -2.575      0.010      -0.282      -0.038
# percent_Alcohol_Impaired                              0.0067      0.008      0.799      0.424      -0.010       0.023
# percent_Uninsured_x                                   0.1480      0.036      4.086      0.000       0.077       0.219
# Average_Daily_PM25                                   -0.2648      0.087     -3.043      0.002      -0.435      -0.094
# percent_Drive_Alone                                   0.0966      0.021      4.499      0.000       0.054       0.139
# percent_Long_Commute___Drives_Alone                   0.0516      0.013      3.908      0.000       0.026       0.077
# percent_Frequent_Physical_Distress                    0.6917      0.246      2.816      0.005       0.210       1.173
# percent_Frequent_Mental_Distress                     -0.4686      0.305     -1.537      0.125      -1.067       0.129
# percent_Insufficient_Sleep                           -0.4377      0.056     -7.836      0.000      -0.547      -0.328
# Household_Income                                   -7.79e-05   1.84e-05     -4.240      0.000      -0.000   -4.19e-05
# Population_y                                      -5.364e-07   4.31e-07     -1.244      0.214   -1.38e-06    3.09e-07
# percent_under_18                                      0.3633      0.063      5.762      0.000       0.240       0.487
# percent_65_and_over                                   0.0920      0.050      1.840      0.066      -0.006       0.190
# percent_African_American                              0.7006      0.125      5.609      0.000       0.456       0.945
# percent_American_Indian_or_Alaskan_Native             0.7827      0.131      5.957      0.000       0.525       1.040
# percent_Asian                                         0.7238      0.149      4.864      0.000       0.432       1.016
# percent_Native_Hawaiian_or_Other_Pacific_Islander     0.9843      0.214      4.608      0.000       0.565       1.403
# percent_Hispanic                                      0.6714      0.123      5.454      0.000       0.430       0.913
# percent_Non_Hispanic_White                            0.6160      0.126      4.878      0.000       0.368       0.864
# percent_Not_Proficient_in_English                    -0.2793      0.079     -3.523      0.000      -0.435      -0.124
# percent_Female                                       -0.0972      0.070     -1.382      0.167      -0.235       0.041
# percent_Rural                                         0.0957      0.006     14.881      0.000       0.083       0.108
# ==============================================================================
# Omnibus:                     1092.737   Durbin-Watson:                   1.975
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            14347.005
# Skew:                           1.842   Prob(JB):                         0.00
# Kurtosis:                      14.514   Cond. No.                     3.98e+07
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.98e+07. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %% [markdown]
# ### Remove the Uninfluential Features

# %%
# Your code here - Remove features which do not appear to be statistically relevant
# Extract the p-value table from the summary and use it to subset our features
summary = model.summary()
p_table = summary.tables[1]
p_table = pd.DataFrame(p_table.data)
p_table.columns = p_table.iloc[0]
p_table = p_table.drop(0)
p_table = p_table.set_index(p_table.columns[0])
p_table['P>|t|'] = p_table['P>|t|'].astype(float)
x_cols = list(p_table[p_table['P>|t|'] < 0.05].index)
x_cols.remove('Intercept')
print(len(p_table), len(x_cols))
print(x_cols[:5])
p_table.head()
# Out:
# 24 18
# ['percent_Physically_Inactive', 'percent_Excessive_Drinking', 'percent_Uninsured_x', 'Average_Daily_PM25', 'percent_Drive_Alone']
# 0                                  coef    std err          t  P>|t|  \
#
# Intercept                      -53.8367     13.393     -4.020  0.000
# percent_Physically_Inactive      0.3933      0.038     10.480  0.000
# percent_Excessive_Drinking      -0.1602      0.062     -2.575  0.010
# percent_Alcohol_Impaired         0.0067      0.008      0.799  0.424
# percent_Uninsured_x              0.1480      0.036      4.086  0.000
#
# 0                               [0.025     0.975]
#
# Intercept                      -80.100    -27.573
# percent_Physically_Inactive      0.320      0.467
# percent_Excessive_Drinking      -0.282     -0.038
# percent_Alcohol_Impaired        -0.010      0.023
# percent_Uninsured_x              0.077      0.219

# %%
predictors = '+'.join(x_cols)
formula = outcome + '~' + predictors
model = ols(formula=formula, data=train).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:      MV_Mortality_Rate   R-squared:                       0.544
# Model:                            OLS   Adj. R-squared:                  0.540
# Method:                 Least Squares   F-statistic:                     154.9
# Date:                Tue, 25 Feb 2020   Prob (F-statistic):               0.00
# Time:                        09:20:39   Log-Likelihood:                -7521.1
# No. Observations:                2356   AIC:                         1.508e+04
# Df Residuals:                    2337   BIC:                         1.519e+04
# Df Model:                          18
# Covariance Type:            nonrobust
# =====================================================================================================================
#                                                         coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------------------------
# Intercept                                           -59.6592     12.837     -4.648      0.000     -84.832     -34.487
# percent_Physically_Inactive                           0.4160      0.037     11.322      0.000       0.344       0.488
# percent_Excessive_Drinking                           -0.1509      0.056     -2.689      0.007      -0.261      -0.041
# percent_Uninsured_x                                   0.1413      0.036      3.927      0.000       0.071       0.212
# Average_Daily_PM25                                   -0.3268      0.085     -3.856      0.000      -0.493      -0.161
# percent_Drive_Alone                                   0.0998      0.021      4.665      0.000       0.058       0.142
# percent_Long_Commute___Drives_Alone                   0.0440      0.013      3.416      0.001       0.019       0.069
# percent_Frequent_Physical_Distress                    0.3344      0.122      2.742      0.006       0.095       0.573
# percent_Insufficient_Sleep                           -0.4619      0.054     -8.548      0.000      -0.568      -0.356
# Household_Income                                  -7.684e-05    1.8e-05     -4.266      0.000      -0.000   -4.15e-05
# percent_under_18                                      0.2808      0.044      6.448      0.000       0.195       0.366
# percent_African_American                              0.7333      0.124      5.891      0.000       0.489       0.977
# percent_American_Indian_or_Alaskan_Native             0.8135      0.131      6.212      0.000       0.557       1.070
# percent_Asian                                         0.7358      0.148      4.982      0.000       0.446       1.025
# percent_Native_Hawaiian_or_Other_Pacific_Islander     1.0317      0.213      4.848      0.000       0.614       1.449
# percent_Hispanic                                      0.7198      0.122      5.902      0.000       0.481       0.959
# percent_Non_Hispanic_White                            0.6496      0.126      5.160      0.000       0.403       0.897
# percent_Not_Proficient_in_English                    -0.2934      0.079     -3.737      0.000      -0.447      -0.139
# percent_Rural                                         0.1036      0.006     17.588      0.000       0.092       0.115
# ==============================================================================
# Omnibus:                     1087.477   Durbin-Watson:                   1.974
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            14073.098
# Skew:                           1.835   Prob(JB):                         0.00
# Kurtosis:                      14.397   Cond. No.                     5.58e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 5.58e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %% [markdown]
# ### Investigate Multicollinearity

# %%
 #x_cols = ['percent_Fair_or_Poor', 'Physically_Unhealthy_Days',  'Mentally_Unhealthy_Days', 'percent_LBW', 'percent_Smokers', 'percent_Obese', 'Food_Environment_Index', 'percent_Physically_Inactive', 'percent_With_Access','percent_Excessive_Drinking', 'percent_Alcohol_Impaired', 'Chlamydia_Rate', 'Teen_Birth_Rate', 'percent_Uninsured_x']

# %%
X = df[x_cols]
vif = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
list(zip(x_cols, vif))
# Out:
# [('percent_Physically_Inactive', 64.16196416093922),
#  ('percent_Excessive_Drinking', 66.94442974673102),
#  ('percent_Uninsured_x', 12.267966453182389),
#  ('Average_Daily_PM25', 39.63623389298265),
#  ('percent_Drive_Alone', 188.81312794796912),
#  ('percent_Long_Commute___Drives_Alone', 12.490551413865903),
#  ('percent_Frequent_Physical_Distress', 147.1763461383445),
#  ('percent_Insufficient_Sleep', 221.57650355212493),
#  ('Household_Income', 60.03601553450771),
#  ('percent_under_18', 66.54875144066422),
#  ('percent_African_American', 18.968748057008387),
#  ('percent_American_Indian_or_Alaskan_Native', 7.213247045411245),
#  ('percent_Asian', 2.854188562996256),
#  ('percent_Native_Hawaiian_or_Other_Pacific_Islander', 1.2445028276695116),
#  ('percent_Hispanic', 20.929619686438482),
#  ('percent_Non_Hispanic_White', 369.66463067221713),
#  ('percent_Not_Proficient_in_English', 4.777959861690783),
#  ('percent_Rural', 10.422677964801558)]

# %%
X.describe()
# Out:
#        percent_Physically_Inactive  percent_Excessive_Drinking  \
# count                  3142.000000                 3142.000000
# mean                     25.699968                   17.411379
# std                       5.173400                    3.242948
# min                       8.400000                    9.265156
# 25%                      22.300000                   15.083152
# 50%                      25.700000                   17.376413
# 75%                      29.200000                   19.666507
# max                      45.100000                   29.440119
#
#        percent_Uninsured_x  Average_Daily_PM25  percent_Drive_Alone  \
# count          3142.000000         3142.000000          3142.000000
# mean             11.136499            8.922852            79.524618
# std               4.940751            2.167390             7.671185
# min               2.068201            0.000000             4.584942
# 25%               7.161386            7.600000            77.213914
# 50%              10.395225            9.300000            80.970663
# 75%              14.011343           10.400000            83.988059
# max              33.453710           19.700000            97.206704
#
#        percent_Long_Commute___Drives_Alone  \
# count                          3142.000000
# mean                             30.955379
# std                              12.396757
# min                               0.000000
# 25%                              21.600000
# 50%                              30.500000
# 75%                              39.500000
# max                              84.500000
#
#        percent_Frequent_Physical_Distress  percent_Insufficient_Sleep  \
# count                         3142.000000                 3142.000000
# mean                            11.990071                   33.042574
# std                              2.325548                    4.156839
# min                              6.936987                   23.028348
# 25%                             10.203211                   30.021654
# 50%                             11.719145                   32.947787
# 75%                             13.531624                   36.113124
# max                             24.618454                   46.707783
#
#        Household_Income  percent_under_18  percent_African_American  \
# count       3142.000000       3142.000000               3142.000000
# mean       51097.243475         22.234860                  8.967079
# std        13501.063257          3.463964                 14.309873
# min        22679.000000          0.000000                  0.000000
# 25%        42275.500000         20.203116                  0.684381
# 50%        48889.000000         22.214871                  2.181373
# 75%        56700.500000         23.993214                 10.175090
# max       136191.000000         41.241927                 85.329609
#
#        percent_American_Indian_or_Alaskan_Native  percent_Asian  \
# count                                3142.000000    3142.000000
# mean                                    2.330171       1.527239
# std                                     7.733871       2.912660
# min                                     0.000000       0.000000
# 25%                                     0.371932       0.447121
# 50%                                     0.633055       0.705543
# 75%                                     1.306277       1.389071
# max                                    92.696903      43.006726
#
#        percent_Native_Hawaiian_or_Other_Pacific_Islander  percent_Hispanic  \
# count                                        3142.000000       3142.000000
# mean                                            0.136884          9.477653
# std                                             0.949352         13.754475
# min                                             0.000000          0.515152
# 25%                                             0.030122          2.299307
# 50%                                             0.058801          4.275689
# 75%                                             0.113605          9.699480
# max                                            47.727273         96.322959
#
#        percent_Non_Hispanic_White  percent_Not_Proficient_in_English  \
# count                 3142.000000                        3142.000000
# mean                    76.285818                           1.731216
# std                     20.149728                           2.900651
# min                      2.760410                           0.000000
# 25%                     64.550805                           0.275766
# 50%                     83.719462                           0.737036
# 75%                     92.508689                           1.864438
# max                     97.922716                          35.305344
#
#        percent_Rural
# count    3142.000000
# mean       58.610718
# std        31.453384
# min         0.000000
# 25%        33.379442
# 50%        59.537911
# 75%        87.557367
# max       100.000000

# %% [markdown]
# ### Perform Another Round of Feature Selection

# %%
vif_scores = list(zip(x_cols, vif))
x_cols = [x for x,vif in vif_scores if vif < 5]
print(len(vif_scores), len(x_cols))
# Out:
# 0 0

# %%
# Your code here - Refit model with subset features
predictors = '+'.join(x_cols)
formula = outcome + "~" + predictors
model = ols(formula=formula, data=train).fit()
model.summary()
# Out:
# ---------------------------------------------------------------------------
# PatsyError                                Traceback (most recent call last)
# <ipython-input-38-5949f15ef63c> in <module>
#       2 predictors = '+'.join(x_cols)
#       3 formula = outcome + "~" + predictors
# ----> 4 model = ols(formula=formula, data=train).fit()
#       5 model.summary()
#
# ~\Anaconda3\lib\site-packages\statsmodels\base\model.py in from_formula(cls, formula, data, subset, drop_cols, *args, **kwargs)
#     157
#     158         tmp = handle_formula_data(data, None, formula, depth=eval_env,
# --> 159                                   missing=missing)
#     160         ((endog, exog), missing_idx, design_info) = tmp
#     161
#
# ~\Anaconda3\lib\site-packages\statsmodels\formula\formulatools.py in handle_formula_data(Y, X, formula, depth, missing)
#      63         if data_util._is_using_pandas(Y, None):
#      64             result = dmatrices(formula, Y, depth, return_type='dataframe',
# ---> 65                                NA_action=na_action)
#      66         else:
#      67             result = dmatrices(formula, Y, depth, return_type='dataframe',
#
# ~\Anaconda3\lib\site-packages\patsy\highlevel.py in dmatrices(formula_like, data, eval_env, NA_action, return_type)
#     308     eval_env = EvalEnvironment.capture(eval_env, reference=1)
#     309     (lhs, rhs) = _do_highlevel_design(formula_like, data, eval_env,
# --> 310                                       NA_action, return_type)
#     311     if lhs.shape[1] == 0:
#     312         raise PatsyError("model is missing required outcome variables")
#
# ~\Anaconda3\lib\site-packages\patsy\highlevel.py in _do_highlevel_design(formula_like, data, eval_env, NA_action, return_type)
#     163         return iter([data])
#     164     design_infos = _try_incr_builders(formula_like, data_iter_maker, eval_env,
# --> 165                                       NA_action)
#     166     if design_infos is not None:
#     167         return build_design_matrices(design_infos, data,
#
# ~\Anaconda3\lib\site-packages\patsy\highlevel.py in _try_incr_builders(formula_like, data_iter_maker, eval_env, NA_action)
#      60                 "ascii-only, or else upgrade to Python 3.")
#      61     if isinstance(formula_like, str):
# ---> 62         formula_like = ModelDesc.from_formula(formula_like)
#      63         # fallthrough
#      64     if isinstance(formula_like, ModelDesc):
#
# ~\Anaconda3\lib\site-packages\patsy\desc.py in from_formula(cls, tree_or_string)
#     162             tree = tree_or_string
#     163         else:
# --> 164             tree = parse_formula(tree_or_string)
#     165         value = Evaluator().eval(tree, require_evalexpr=False)
#     166         assert isinstance(value, cls)
#
# ~\Anaconda3\lib\site-packages\patsy\parse_formula.py in parse_formula(code, extra_operators)
#     146     tree = infix_parse(_tokenize_formula(code, operator_strings),
#     147                        operators,
# --> 148                        _atomic_token_types)
#     149     if not isinstance(tree, ParseNode) or tree.type != "~":
#     150         tree = ParseNode("~", None, [tree], tree.origin)
#
# ~\Anaconda3\lib\site-packages\patsy\infix_parser.py in infix_parse(tokens, operators, atomic_types, trace)
#     220     if want_noun:
#     221         raise PatsyError("expected a noun, but instead the expression ended",
# --> 222                             c.op_stack[-1].token.origin)
#     223
#     224     while c.op_stack:
#
# PatsyError: expected a noun, but instead the expression ended
#     MV_Mortality_Rate~
#                      ^

# %%
X.isna().sum()
# Out:
# percent_Physically_Inactive                          0
# percent_Excessive_Drinking                           0
# percent_Uninsured_x                                  0
# Average_Daily_PM25                                   0
# percent_Drive_Alone                                  0
# percent_Long_Commute___Drives_Alone                  0
# percent_Frequent_Physical_Distress                   0
# percent_Insufficient_Sleep                           0
# Household_Income                                     0
# percent_under_18                                     0
# percent_African_American                             0
# percent_American_Indian_or_Alaskan_Native            0
# percent_Asian                                        0
# percent_Native_Hawaiian_or_Other_Pacific_Islander    0
# percent_Hispanic                                     0
# percent_Non_Hispanic_White                           0
# percent_Not_Proficient_in_English                    0
# percent_Rural                                        0
# dtype: int64

# %% [markdown]
# ### Check the Normality Assumption
# Check whether the normality assumption holds for your model.

# %%
fig = sm.graphics.qqplot(model.resid, dist=stats.norm, line='45', fit=True)

# %% [markdown]
# ### Check Homoscedasticity Assumption
# Check whether the model's errors are indeed homoscedastic or if they violate this principle and display heteroscedasticity.

# %%
print(len(train[x_cols]))
print(len(train))
plt.scatter(model.predict(train[x_cols]), model.resid)
plt.plot(model.predict(train[x_cols]), [0 for i in range(len(train))])
# Out:
# 2356
# 2356
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\patsy\compat.py in call_and_wrap_exc(msg, origin, f, *args, **kwargs)
#      35     try:
# ---> 36         return f(*args, **kwargs)
#      37     except Exception as e:
#
# ~\Anaconda3\lib\site-packages\patsy\eval.py in eval(self, expr, source_name, inner_namespace)
#     165         return eval(code, {}, VarLookupDict([inner_namespace]
# --> 166                                             + self._namespaces))
#     167
#
# <string> in <module>
#
# NameError: name 'percent_Asian' is not defined
#
# The above exception was the direct cause of the following exception:
#
# PatsyError                                Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\statsmodels\base\model.py in predict(self, exog, transform, *args, **kwargs)
#    1013             try:
# -> 1014                 exog = dmatrix(design_info, exog, return_type="dataframe")
#    1015             except Exception as exc:
#
# ~\Anaconda3\lib\site-packages\patsy\highlevel.py in dmatrix(formula_like, data, eval_env, NA_action, return_type)
#     290     (lhs, rhs) = _do_highlevel_design(formula_like, data, eval_env,
# --> 291                                       NA_action, return_type)
#     292     if lhs.shape[1] != 0:
#
# ~\Anaconda3\lib\site-packages\patsy\highlevel.py in _do_highlevel_design(formula_like, data, eval_env, NA_action, return_type)
#     168                                      NA_action=NA_action,
# --> 169                                      return_type=return_type)
#     170     else:
#
# ~\Anaconda3\lib\site-packages\patsy\build.py in build_design_matrices(design_infos, data, NA_action, return_type, dtype)
#     887             if factor_info not in factor_info_to_values:
# --> 888                 value, is_NA = _eval_factor(factor_info, data, NA_action)
#     889                 factor_info_to_isNAs[factor_info] = is_NA
#
# ~\Anaconda3\lib\site-packages\patsy\build.py in _eval_factor(factor_info, data, NA_action)
#      62     factor = factor_info.factor
# ---> 63     result = factor.eval(factor_info.state, data)
#      64     # Returns either a 2d ndarray, or a DataFrame, plus is_NA mask
#
# ~\Anaconda3\lib\site-packages\patsy\eval.py in eval(self, memorize_state, data)
#     565                           memorize_state,
# --> 566                           data)
#     567
#
# ~\Anaconda3\lib\site-packages\patsy\eval.py in _eval(self, code, memorize_state, data)
#     550                                  code,
# --> 551                                  inner_namespace=inner_namespace)
#     552
#
# ~\Anaconda3\lib\site-packages\patsy\compat.py in call_and_wrap_exc(msg, origin, f, *args, **kwargs)
#      42             # Use 'exec' to hide this syntax from the Python 2 parser:
# ---> 43             exec("raise new_exc from e")
#      44         else:
#
# ~\Anaconda3\lib\site-packages\patsy\compat.py in <module>
#
# PatsyError: Error evaluating factor: NameError: name 'percent_Asian' is not defined
#     MV_Mortality_Rate~percent_Asian+percent_Native_Hawaiian_or_Other_Pacific_Islander+percent_Not_Proficient_in_English
#                       ^^^^^^^^^^^^^
#
# During handling of the above exception, another exception occurred:
#
# PatsyError                                Traceback (most recent call last)
# <ipython-input-42-c3bb7e2e2113> in <module>
#       1 print(len(train[x_cols]))
#       2 print(len(train))
# ----> 3 plt.scatter(model.predict(train[x_cols]), model.resid)
#       4 plt.plot(model.predict(train[x_cols]), [0 for i in range(len(train))])
#
# ~\Anaconda3\lib\site-packages\statsmodels\base\model.py in predict(self, exog, transform, *args, **kwargs)
#    1019                        '\n\nThe original error message returned by patsy is:\n'
#    1020                        '{0}'.format(str(str(exc))))
# -> 1021                 raise exc.__class__(msg)
#    1022             if orig_exog_len > len(exog) and not is_dict:
#    1023                 import warnings
#
# PatsyError: predict requires that you use a DataFrame when predicting from a model
# that was created using the formula api.
#
# The original error message returned by patsy is:
# Error evaluating factor: NameError: name 'percent_Asian' is not defined
#     MV_Mortality_Rate~percent_Asian+percent_Native_Hawaiian_or_Other_Pacific_Islander+percent_Not_Proficient_in_English
#                       ^^^^^^^^^^^^^

# %% [markdown]
# #### This is for the description data

# %% [markdown]
# ### Make Additional Refinements
# Check for outliers

# %%
df.percent_Smokers.hist() # using smokers for example

# %%
# Teen_Birth_Rate
df.Teen_Birth_Rate.hist()

# %%
for i in range(80,100):
    q = i/100
    print("{} percentile: {}".format(q, df.Teen_Birth_Rate.quantile(q=q)))
# Out:
# 0.8 percentile: 44.021632146200005
# 0.81 percentile: 44.57537042527999
# 0.82 percentile: 45.13786282708
# 0.83 percentile: 45.7437253245
# 0.84 percentile: 46.408010351360005
# 0.85 percentile: 47.19902860679999
# 0.86 percentile: 48.28781243336
# 0.87 percentile: 49.08266710231
# 0.88 percentile: 49.87582828444
# 0.89 percentile: 50.517701593030004
# 0.9 percentile: 51.372594874
# 0.91 percentile: 52.51232592673
# 0.92 percentile: 53.86830442256
# 0.93 percentile: 54.719212391510005
# 0.94 percentile: 56.57725777354
# 0.95 percentile: 58.71437884169999
# 0.96 percentile: 60.65668465383999
# 0.97 percentile: 63.949185825849995
# 0.98 percentile: 67.52576746547999
# 0.99 percentile: 73.87815089257002

# %% [markdown]
# ### To remove extreme outliers we could use a function like this to remove outliers......

# %%
# use code similar to this to strip outliers
# once it's gone it's gone => 

limit = 100

orig_tot = len(df)
df = df[df.Teen_Birth_Rate < limit] # Subsetting to remove extreme outliers
print('Percent removed:', (orig_tot -len(df))/orig_tot)
df.list_price = df.Teen_Birth_Rate.map(np.log) # Applying a log transformation
train, test = train_test_split(df)

# Refit model with subset features
predictors = '+'.join(x_cols)
formula = outcome + "~" + predictors
model = ols(formula=formula, data=train).fit()
model.summary()

# %% [markdown]
# ### Check the Homoscedasticity Assumption

# %%
fig = sm.graphics.qqplot(model.resid, dist=stats.norm, line='45', fit=True)

# %%
plt.scatter(model.predict(train[x_cols]), model.resid)
plt.plot(model.predict(train[x_cols]), [0 for i in range(len(train))])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\patsy\compat.py in call_and_wrap_exc(msg, origin, f, *args, **kwargs)
#      35     try:
# ---> 36         return f(*args, **kwargs)
#      37     except Exception as e:
#
# ~\Anaconda3\lib\site-packages\patsy\eval.py in eval(self, expr, source_name, inner_namespace)
#     165         return eval(code, {}, VarLookupDict([inner_namespace]
# --> 166                                             + self._namespaces))
#     167
#
# <string> in <module>
#
# NameError: name 'percent_Asian' is not defined
#
# The above exception was the direct cause of the following exception:
#
# PatsyError                                Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\statsmodels\base\model.py in predict(self, exog, transform, *args, **kwargs)
#    1013             try:
# -> 1014                 exog = dmatrix(design_info, exog, return_type="dataframe")
#    1015             except Exception as exc:
#
# ~\Anaconda3\lib\site-packages\patsy\highlevel.py in dmatrix(formula_like, data, eval_env, NA_action, return_type)
#     290     (lhs, rhs) = _do_highlevel_design(formula_like, data, eval_env,
# --> 291                                       NA_action, return_type)
#     292     if lhs.shape[1] != 0:
#
# ~\Anaconda3\lib\site-packages\patsy\highlevel.py in _do_highlevel_design(formula_like, data, eval_env, NA_action, return_type)
#     168                                      NA_action=NA_action,
# --> 169                                      return_type=return_type)
#     170     else:
#
# ~\Anaconda3\lib\site-packages\patsy\build.py in build_design_matrices(design_infos, data, NA_action, return_type, dtype)
#     887             if factor_info not in factor_info_to_values:
# --> 888                 value, is_NA = _eval_factor(factor_info, data, NA_action)
#     889                 factor_info_to_isNAs[factor_info] = is_NA
#
# ~\Anaconda3\lib\site-packages\patsy\build.py in _eval_factor(factor_info, data, NA_action)
#      62     factor = factor_info.factor
# ---> 63     result = factor.eval(factor_info.state, data)
#      64     # Returns either a 2d ndarray, or a DataFrame, plus is_NA mask
#
# ~\Anaconda3\lib\site-packages\patsy\eval.py in eval(self, memorize_state, data)
#     565                           memorize_state,
# --> 566                           data)
#     567
#
# ~\Anaconda3\lib\site-packages\patsy\eval.py in _eval(self, code, memorize_state, data)
#     550                                  code,
# --> 551                                  inner_namespace=inner_namespace)
#     552
#
# ~\Anaconda3\lib\site-packages\patsy\compat.py in call_and_wrap_exc(msg, origin, f, *args, **kwargs)
#      42             # Use 'exec' to hide this syntax from the Python 2 parser:
# ---> 43             exec("raise new_exc from e")
#      44         else:
#
# ~\Anaconda3\lib\site-packages\patsy\compat.py in <module>
#
# PatsyError: Error evaluating factor: NameError: name 'percent_Asian' is not defined
#     MV_Mortality_Rate~percent_Asian+percent_Native_Hawaiian_or_Other_Pacific_Islander+percent_Not_Proficient_in_English
#                       ^^^^^^^^^^^^^
#
# During handling of the above exception, another exception occurred:
#
# PatsyError                                Traceback (most recent call last)
# <ipython-input-47-adb90f0bb619> in <module>
# ----> 1 plt.scatter(model.predict(train[x_cols]), model.resid)
#       2 plt.plot(model.predict(train[x_cols]), [0 for i in range(len(train))])
#
# ~\Anaconda3\lib\site-packages\statsmodels\base\model.py in predict(self, exog, transform, *args, **kwargs)
#    1019                        '\n\nThe original error message returned by patsy is:\n'
#    1020                        '{0}'.format(str(str(exc))))
# -> 1021                 raise exc.__class__(msg)
#    1022             if orig_exog_len > len(exog) and not is_dict:
#    1023                 import warnings
#
# PatsyError: predict requires that you use a DataFrame when predicting from a model
# that was created using the formula api.
#
# The original error message returned by patsy is:
# Error evaluating factor: NameError: name 'percent_Asian' is not defined
#     MV_Mortality_Rate~percent_Asian+percent_Native_Hawaiian_or_Other_Pacific_Islander+percent_Not_Proficient_in_English
#                       ^^^^^^^^^^^^^

# %% [markdown]
# ### Interactions

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
features = ['percent_Physically_Inactive',
         'percent_Excessive_Drinking',
         'percent_Alcohol_Impaired',
         'percent_Uninsured_x',
         'Average_Daily_PM25',
         'percent_Drive_Alone',
         'percent_Long_Commute___Drives_Alone',
         'percent_Frequent_Physical_Distress',
         'percent_Frequent_Mental_Distress',
         'percent_Insufficient_Sleep',
         'Household_Income',
         'Population_y',
         'percent_under_18',
         'percent_65_and_over',
         'percent_African_American',
         'percent_American_Indian_or_Alaskan_Native',
         'percent_Asian',
         'percent_Native_Hawaiian_or_Other_Pacific_Islander',
         'percent_Hispanic',
         'percent_Non_Hispanic_White',
         'percent_Not_Proficient_in_English',
         'percent_Female',
         'percent_Rural'
        ]

# %% [markdown]
# ### See how interactions improve your baseline

# %%
def build_interaction_rm(varname, description):
    regression_h = LinearRegression()
    regression_m = LinearRegression()
    regression_l = LinearRegression()
    regression_h.fit(high_rm[varname].values.reshape(-1, 1), high_rm['target'])
    regression_m.fit(med_rm[varname].values.reshape(-1, 1), med_rm['target'])
    regression_l.fit(low_rm[varname].values.reshape(-1, 1), low_rm['target'])

    # Make predictions using the testing set
    pred_high = regression_h.predict(high_rm[varname].values.reshape(-1, 1))
    pred_med = regression_m.predict(med_rm[varname].values.reshape(-1, 1))
    pred_low = regression_l.predict(low_rm[varname].values.reshape(-1, 1))

    # The coefficients
    print(regression_h.coef_)
    print(regression_m.coef_)
    print(regression_l.coef_)

    # Plot outputs
    plt.figure(figsize=(12,7))
    plt.scatter(high_rm[varname], high_rm['target'],  color='blue', alpha = 0.3, label = 'more rooms')
    plt.scatter(med_rm[varname], med_rm['target'],  color='red', alpha = 0.3, label = 'medium rooms')
    plt.scatter(low_rm[varname], low_rm['target'],  color='orange', alpha = 0.3, label = 'low amount of rooms')

    plt.plot(low_rm[varname], pred_low,  color='orange', linewidth=2)
    plt.plot(med_rm[varname], pred_med,  color='red', linewidth=2)
    plt.plot(high_rm[varname], pred_high,  color='blue', linewidth=2)
    plt.ylabel('house value')
    plt.xlabel(description)
    plt.legend()

# %% [markdown]
# Using a 10-fold cross-validation to build a model using all the above interactions

# %% [markdown]
# ### Baseline

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings
#warnings.filterwarnings('ignore')

from sklearn.linear_model import LinearRegression
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold
from sklearn.preprocessing import scale

# %%
data = df[features]#.drop(column='MV_Mortality_Rate')

y = pd.DataFrame(df.MV_Mortality_Rate)#, columns=[target])
X = pd.DataFrame(data, columns = data.columns)

X_scaled = scale(X)
X_scaled = pd.DataFrame(X_scaled, columns=X.columns)

all_data = pd.concat([y, X_scaled], axis=1)
regression = LinearRegression()

crossvalidation = KFold(n_splits=10, shuffle=True, random_state=1)
baseline = np.mean(cross_val_score(regression, X_scaled, y, scoring='r2', cv=crossvalidation))
baseline
# Out:
# 0.5395507266172348

# %% [markdown]
# ### Interactions

# %%
from itertools import combinations
combinations = list(combinations(data.columns, 2))

interactions = []
data = X_scaled.copy()
for comb in combinations:
    data['interaction'] = data[comb[0]] * data[comb[1]]
    score = np.mean(cross_val_score(regression, data, y, scoring='r2', cv=crossvalidation))
    if score > baseline: interactions.append((comb[0], comb[1], round(score, 3)))
            
print('Top 7 interactions: %s' %sorted(interactions, key=lambda inter: inter[2], reverse=True)[:7])
# Out:
# Top 7 interactions: [('percent_Drive_Alone', 'percent_American_Indian_or_Alaskan_Native', 0.557), ('Average_Daily_PM25', 'percent_American_Indian_or_Alaskan_Native', 0.554), ('percent_Drive_Alone', 'percent_Non_Hispanic_White', 0.553), ('percent_Uninsured_x', 'percent_Drive_Alone', 0.552), ('Average_Daily_PM25', 'percent_Drive_Alone', 0.552), ('Average_Daily_PM25', 'percent_Frequent_Physical_Distress', 0.55), ('Average_Daily_PM25', 'percent_Frequent_Mental_Distress', 0.55)]

# %%
df_inter = X_scaled.copy()
ls_interactions = sorted(interactions, key=lambda inter: inter[2], reverse=True)[:7]
for inter in ls_interactions:
    df_inter[inter[0] + '_' + inter[1]] = X[inter[0]] * X[inter[1]]

# %% [markdown]
# ### Polynomials

# %%
from sklearn.preprocessing import PolynomialFeatures
polynomials = []
for col in X.columns:
    for degree in [2, 3, 4]:
        data = X_scaled.copy()
        poly = PolynomialFeatures(degree, include_bias=False)
        X_transformed = poly.fit_transform(X[[col]])
        data = pd.concat([data.drop(col, axis=1),pd.DataFrame(X_transformed)], axis=1)
        score = np.mean(cross_val_score(regression, data, y, scoring='r2', cv=crossvalidation))
        if score > baseline: polynomials.append((col, degree, round(score, 3)))
print('Top 10 polynomials: %s' %sorted(polynomials, key=lambda poly: poly[2], reverse=True)[:10])
# Out:
# Top 10 polynomials: [('Average_Daily_PM25', 4, 0.546), ('percent_Drive_Alone', 2, 0.546), ('percent_Long_Commute___Drives_Alone', 4, 0.546), ('percent_Physically_Inactive', 2, 0.543), ('percent_Physically_Inactive', 3, 0.543), ('percent_Physically_Inactive', 4, 0.543), ('Average_Daily_PM25', 3, 0.543), ('percent_Insufficient_Sleep', 2, 0.543), ('percent_Insufficient_Sleep', 3, 0.543), ('percent_Insufficient_Sleep', 4, 0.543)]

# %%
polynom = pd.DataFrame(polynomials)
polynom.groupby([0], sort=False)[2].max()
# Out:
# 0
# percent_Physically_Inactive            0.543
# percent_Excessive_Drinking             0.542
# percent_Alcohol_Impaired               0.542
# percent_Uninsured_x                    0.542
# Average_Daily_PM25                     0.546
# percent_Drive_Alone                    0.546
# percent_Long_Commute___Drives_Alone    0.546
# percent_Frequent_Mental_Distress       0.540
# percent_Insufficient_Sleep             0.543
# Household_Income                       0.540
# percent_under_18                       0.540
# percent_65_and_over                    0.540
# percent_African_American               0.540
# percent_Asian                          0.541
# percent_Hispanic                       0.541
# percent_Non_Hispanic_White             0.543
# percent_Female                         0.540
# Name: 2, dtype: float64

# %%
for col in ['percent_Alcohol_Impaired', 'percent_Excessive_Drinking']:
    poly = PolynomialFeatures(4, include_bias=False)
    X_transformed = poly.fit_transform(X[[col]])
    colnames= [col, col + '_' + '2',  col + '_' + '3', col + '_' + '4']
    df_inter = pd.concat([df_inter.drop(col, axis=1), pd.DataFrame(X_transformed, columns=colnames)], axis=1)
